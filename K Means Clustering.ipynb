# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Mall_Customers.csv')

# %%
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
x = dataset.iloc[:, 1:].values

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
x[:,0] = le.fit_transform(x[:,0])

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 10):
  kmeans = KMeans(n_clusters = i, init = 'k-means++')
  kmeans.fit(x)
  wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1, 10), wcss)

# %%
kmeans = KMeans(n_clusters = 5, init = 'k-means++')
y_kmeans = kmeans.fit_predict(x)

# %%
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 3], c = 'red')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 3], c = 'blue')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 3], c = 'green')
plt.scatter(x[y_kmeans == 3, 0], x[y_kmeans == 3, 3], c = 'yellow')
plt.scatter(x[y_kmeans == 4, 0], x[y_kmeans == 4, 3], c = 'orange')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 3], c = 'black')
plt.xlabel('Gender')
plt.ylabel('Spending Score')
# Out:
# Text(0, 0.5, 'Spending Score')

# %%
plt.scatter(x[y_kmeans == 0, 1], x[y_kmeans == 0, 3], c = 'red')
plt.scatter(x[y_kmeans == 1, 1], x[y_kmeans == 1, 3], c = 'blue')
plt.scatter(x[y_kmeans == 2, 1], x[y_kmeans == 2, 3], c = 'green')
plt.scatter(x[y_kmeans == 3, 1], x[y_kmeans == 3, 3], c = 'yellow')
plt.scatter(x[y_kmeans == 4, 1], x[y_kmeans == 4, 3], c = 'orange')
plt.scatter(kmeans.cluster_centers_[:, 1], kmeans.cluster_centers_[:, 3], c = 'black')
plt.xlabel('Age')
plt.ylabel('Spending Score')
# Out:
# Text(0, 0.5, 'Spending Score')

# %%
plt.scatter(x[y_kmeans == 0, 2], x[y_kmeans == 0, 3], c = 'red')
plt.scatter(x[y_kmeans == 1, 2], x[y_kmeans == 1, 3], c = 'blue')
plt.scatter(x[y_kmeans == 2, 2], x[y_kmeans == 2, 3], c = 'green')
plt.scatter(x[y_kmeans == 3, 2], x[y_kmeans == 3, 3], c = 'yellow')
plt.scatter(x[y_kmeans == 4, 2], x[y_kmeans == 4, 3], c = 'orange')
plt.scatter(kmeans.cluster_centers_[:, 2], kmeans.cluster_centers_[:, 3], c = 'black')
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
# Out:
# Text(0, 0.5, 'Spending Score')
